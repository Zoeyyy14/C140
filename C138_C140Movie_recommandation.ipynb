# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoeyyy14/C140/blob/main/C138_C140Movie_recommandation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-cc25bda1-289c-4e7d-9b72-02f28368e3c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc25bda1-289c-4e7d-9b72-02f28368e3c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
#mkdir=make directory
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d tmdb/tmdb-movie-metadata
# Out:
# ...
#  56% 5.00M/8.89M [00:00<00:00, 16.3MB/s]
# 100% 8.89M/8.89M [00:00<00:00, 25.6MB/s]

# %%
# !unzip tmdb-movie-metadata.zip
# Out:
# Archive:  tmdb-movie-metadata.zip
#   inflating: tmdb_5000_credits.csv
#   inflating: tmdb_5000_movies.csv

# %%
import pandas as pd
import numpy as np
df1=pd.read_csv("tmdb_5000_credits.csv")
df1.head()
# Out:
#    movie_id  ...                                               crew
# 0     19995  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1       285  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2    206647  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     49026  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     49529  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 4 columns]

# %%
df2=pd.read_csv("tmdb_5000_movies.csv")
df2.head()
# Out:
#       budget  ... vote_count
# 0  237000000  ...      11800
# 1  300000000  ...       4500
# 2  245000000  ...       4466
# 3  250000000  ...       9106
# 4  260000000  ...       2124
#
# [5 rows x 20 columns]

# %%
df1.columns=["id","title","cast","crew"]
df2=df2.merge(df1, on="id")
df2.head()
# Out:
#       budget  ...                                               crew
# 0  237000000  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  300000000  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  245000000  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  250000000  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  260000000  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %%
#C139
C=df2["vote_average"].mean()
print(C)
# Out:
# 6.092171559442011

# %%
m=df2["vote_count"].quantile(0.9)
print(m)
# Out:
# 1838.4000000000015

# %%
q_movie=df2.copy().loc[df2["vote_count"]>=m]
print(q_movie.shape)
# Out:
# (481, 23)

# %%
def rating(x,m=m,C=C):
  v=x["vote_count"]
  R=x["vote_average"]
  return ((v/(v+m))*R)+((m/(v+m))*C)
q_movie["score"]=q_movie.apply(rating,axis=1)
q_movie=q_movie.sort_values("score",ascending=False)
q_movie[["original_title","vote_count","vote_average","score"]].head()
# Out:
#                 original_title  vote_count  vote_average     score
# 1881  The Shawshank Redemption        8205           8.5  8.059258
# 662                 Fight Club        9413           8.3  7.939256
# 65             The Dark Knight       12002           8.2  7.920020
# 3232              Pulp Fiction        8428           8.3  7.904645
# 96                   Inception       13752           8.1  7.863239

# %%
import plotly.express as px
fig=px.bar((q_movie.head(10).sort_values("score",ascending=False)),x="score",y="original_title",orientation="h")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="93342196-8d9f-4dca-8e18-9255a0ec20a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("93342196-8d9f-4dca-8e18-9255a0ec20a5")) {
#                     Plotly.newPlot(
#                         '93342196-8d9f-4dca-8e18-9255a0ec20a5',
# ...

# %%
#C140
df2[["original_title","cast","crew","keywords","genres"]].head(3)
# Out:
#                              original_title  ...                                             genres
# 0                                    Avatar  ...  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  Pirates of the Caribbean: At World's End  ...  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2                                   Spectre  ...  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
# [3 rows x 5 columns]

# %%
from ast import literal_eval
features=["cast", "crew", "keywords", "genres"]
for feature in features:
  df2[feature]=df2[feature].apply(literal_eval)
df2.dtypes
# Out:
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title_x                  object
# vote_average            float64
# vote_count                int64
# title_y                  object
# cast                     object
# crew                     object
# dtype: object

# %%
def get_director(x):
  for i in x:
    if i["job"]=="Director":
      return i["name"]
  return np.nan
df2["director"]=df2["crew"].apply(get_director)
df2.head(10)
# Out:
#       budget  ...           director
# 0  237000000  ...      James Cameron
# 1  300000000  ...     Gore Verbinski
# 2  245000000  ...         Sam Mendes
# 3  250000000  ...  Christopher Nolan
# 4  260000000  ...     Andrew Stanton
# 5  258000000  ...          Sam Raimi
# 6  260000000  ...       Byron Howard
# 7  280000000  ...        Joss Whedon
# 8  250000000  ...        David Yates
# 9  250000000  ...        Zack Snyder
#
# [10 rows x 24 columns]

# %%
def get_list(x):
  if isinstance(x,list):
    names=[i["name"]for i in x]
    return names
  return[]
features=["cast", "keywords","genres"]
for feature in features:
  df2[feature]=df2[feature].apply(get_list)
df2.head()
# Out:
#       budget  ...           director
# 0  237000000  ...      James Cameron
# 1  300000000  ...     Gore Verbinski
# 2  245000000  ...         Sam Mendes
# 3  250000000  ...  Christopher Nolan
# 4  260000000  ...     Andrew Stanton
#
# [5 rows x 24 columns]

# %%
df2[["original_title","cast","director","keywords","genres"]].head(3)
# Out:
#                              original_title  ...                                         genres
# 0                                    Avatar  ...  [Action, Adventure, Fantasy, Science Fiction]
# 1  Pirates of the Caribbean: At World's End  ...                   [Adventure, Fantasy, Action]
# 2                                   Spectre  ...                     [Action, Adventure, Crime]
#
# [3 rows x 5 columns]

# %%
def clean(x):
  if isinstance(x,list):
    return[str.lower(i.replace(" ",""))for i in x]
  else:
    if isinstance(x,str):
      return str.lower(x.replace(" ",""))
    else:
      return ""
features=["cast", "keywords","director","genres"]
for feature in features:
  df2[feature]=df2[feature].apply(clean)
df2.head()
# Out:
#       budget  ...          director
# 0  237000000  ...      jamescameron
# 1  300000000  ...     goreverbinski
# 2  245000000  ...         sammendes
# 3  250000000  ...  christophernolan
# 4  260000000  ...     andrewstanton
#
# [5 rows x 24 columns]

# %%
a=["Hello","How","Are","You"]
" ".join(a)
# Out:
# 'Hello How Are You'

# %%
def create_soup(x):
  return " ".join(x["keywords"])+" "+" ".join(x["cast"])+" "+" ".join(x["director"])+" "+" ".join(x["genres"])
df2["soup"]=df2.apply(create_soup,axis=1)
df2.head()
# Out:
#       budget  ...                                               soup
# 0  237000000  ...  cultureclash future spacewar spacecolony socie...
# 1  300000000  ...  ocean drugabuse exoticisland eastindiatradingc...
# 2  245000000  ...  spy basedonnovel secretagent sequel mi6 britis...
# 3  250000000  ...  dccomics crimefighter terrorist secretidentity...
# 4  260000000  ...  basedonnovel mars medallion spacetravel prince...
#
# [5 rows x 25 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
count=CountVectorizer(stop_words="english")
count_matrix=count.fit_transform(df2["soup"])

# %%
cosine_sim2=cosine_similarity(count_matrix,count_matrix)
df2=df2.reset_index()
indices=pd.Series(df2.index,index=df2["original_title"])

# %%
def get_recommandations(title,cosine_sim):
  idx=indices[title]
  sim_scores=list(enumerate(cosine_sim[idx]))
  sim_scores=sorted(sim_scores,key=lambda x:x[1],reverse=True)
  sim_scores=sim_scores[1:11]
  movie_indices=[i[0]for i in sim_scores]
  return df2["original_title"].iloc[movie_indices]

# %%
get_recommandations("Inception",cosine_sim2)
# Out:
# 4401                      The Helix... Loaded
# 1932                                   Sheena
# 1447                                Knock Off
# 607     Sky Captain and the World of Tomorrow
# 2644                                Ong Bak 2
# 1001    Street Fighter: The Legend of Chun-Li
# 1273                              Extreme Ops
# 4589                                   Fabled
# 4734                                 Echo Dr.
# 1715                                  Timecop
# Name: original_title, dtype: object
